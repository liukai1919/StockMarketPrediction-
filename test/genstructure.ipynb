# %%
import os

def list_files(startpath, exclude_dirs=None):
    if exclude_dirs is None:
        exclude_dirs = []

    for root, dirs, files in os.walk(startpath):
        # Filter out directories to exclude
        dirs[:] = [d for d in dirs if d not in exclude_dirs]

        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * level
        print(f'{indent}{os.path.basename(root)}/')
        
        # Only print files if not in the 'models' directory
        if 'models' not in root:
            subindent = ' ' * 4 * (level + 1)
            for f in files:
                print(f'{subindent}{f}')

# Get the parent directory of the current working directory
parent_directory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# List files starting from the parent directory, excluding 'data', '.git', and files under 'models'
list_files(parent_directory, exclude_dirs=['data', '.git'])
# Out:
# StockMarketPrediction-/
#     Distribution of Sentiment Labels When Stock Change.png
#     .DS_Store
#     LICENSE
#     requirements.txt
#     README.md
#     .gitignore
#     .env
#     test/
#         modeltest.ipynb
#         new.ipynb
#         regression.ipynb
#         genstructure.ipynb
#         APItest.ipynb
#     images/
#         Distribution of Sentiment Labels When Stock Change.png
#         close_output.png
#     utils/
#         .DS_Store
#         __init__.py
#         APIs.py
#         fianacialtools.py
#         __pycache__/
#             enhenceedLSTM.cpython-311.pyc
#             LSTM.cpython-311.pyc
#             APIs.cpython-311.pyc
#             fianacialtools.cpython-311.pyc
#             __init__.cpython-311.pyc
#     models/
#         distilbert-base-uncased-financial-finetune/
#             checkpoint-597/
#             checkpoint-1194/
#     .venv/
#         .DS_Store
#         pyvenv.cfg
#         bin/
#             pyftsubset
#             pip3.8
# ...
