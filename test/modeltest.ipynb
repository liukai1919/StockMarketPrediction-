# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="liukai1987/distilbert-base-uncased-financial-finetune")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# config.json:   0%|          | 0.00/784 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
import pandas as pd

df = pd.read_csv('../data/Amazon.csv')
df.head()
# Out:
#                                                  url  \
# 0  https://www.benzinga.com/markets/options/23/09...
# 1  https://www.investors.com/news/technology/amaz...
# 2  https://www.benzinga.com/insights/options/24/0...
# 3  https://www.benzinga.com/insights/news/24/10/4...
# 4  https://www.barrons.com/articles/-amazon-care-...
#
#                               authorsByline                         articleId  \
# 0                         Benzinga Insights  3e0977d3ab0c46a3a63f3c54be31559c
# 1  PATRICK SEITZ, Investor's Business Daily  d87e2715819b4c768df970877cc3adc9
# 2                         Benzinga Insights  ccd56c53f85e4048a18d3c5558d24962
# 3                         Benzinga Insights  3269f58619154c55b08d8b58dc68b4a5
# 4                            Eric J. Savitz  078d5e6f599a4ecdbcd64840242c1757
#
#                           clusterId  \
# 0  5a7db019e1784220b7f9f1820f7d76de
# 1  43fcd4eaf99c4e658f2ea8937bb3b1a1
# 2  4dfd303d36194063a2259979e2f08951
# 3  f48106320e3542d196af0d216b604eee
# 4  7352bfbd21434aa4bab91cf5eb4514a1
#
#                                               source  \
# 0  {"domain":"benzinga.com","paywall":false,"loca...
# 1  {"domain":"investors.com","paywall":true,"loca...
# 2  {"domain":"benzinga.com","paywall":false,"loca...
# 3  {"domain":"benzinga.com","paywall":false,"loca...
# 4  {"domain":"barrons.com","paywall":true,"locati...
#
#                                             imageUrl country language  \
# 0  https://cdn.benzinga.com/files/images/story/20...      us       en
# 1  https://www.investors.com/wp-content/uploads/2...      us       en
# 2  https://cdn.benzinga.com/files/images/story/20...      us       en
# 3  https://cdn.benzinga.com/files/images/story/20...      us       en
# 4        https://images.barrons.com/im-608344/social      us       en
#
#                      pubDate                           addDate  ...  \
# 0  2023-09-01T20:18:43+00:00  2023-09-01T20:28:10.586136+00:00  ...
# 1  2022-08-05T13:57:00+00:00  2022-08-05T14:03:06.437850+00:00  ...
# 2  2024-09-25T17:30:46+00:00  2024-09-25T17:47:54.002068+00:00  ...
# 3  2024-10-23T15:31:30+00:00  2024-10-25T23:31:30.291124+00:00  ...
# 4  2022-08-24T23:18:00+00:00  2022-08-24T23:39:20.583059+00:00  ...
#
#                                              summary  translation  \
# 0  Amazon.com (NASDAQ:AMZN) has taken a bearish s...          NaN
# 1  E-commerce giant Amazon (AMZN) on Friday annou...          NaN
# 2  Amazon.com (NASDAQ:AMZN) has seen unusual acti...          NaN
# 3  Amazon.com (NASDAQ:AMZN) shares are currently ...          NaN
# 4  Amazon is shutting down Amazon Care, a healthc...          NaN
#
#   translatedTitle translatedDescription locations reprint  \
# 0             NaN                   NaN        []   False
# 1             NaN                   NaN        []   False
# 2             NaN                   NaN        []   False
# 3             NaN                   NaN        []   False
# 4             NaN                   NaN        []   False
#
#                      reprintGroupId places people  translatedSummary
# 0  4ee337b9dcbf4525a81b7a5183664bf0     []     []                NaN
# 1  5ecef2bfc08a4829abc39e5bc95487d2    NaN    NaN                NaN
# 2  86d94c97ebcf4d8ebe50e81f3d83636a     []     []                NaN
# 3  dd83e1c061cb4a8eb4013af7bbe6e274     []     []                NaN
# 4  bdf340ec49bc4236af501bb87bbb88f3    NaN    NaN                NaN
#
# [5 rows x 37 columns]

# %%
content = df['summary']
print(content[0])

pipe("""You probably have not missed the news that Warren Buffett has already sold half the stock from his largest public markets investment, Apple Inc. (NASDAQ:AAPL). It was a phenomenal investment for Berkshire. Over the course of seven years or so, it brought a profit of well over USD 100 billion. Apple comprised a very large position within Berkshire’s public portfolio, and this was the reason we avoided Apple stock outright during that time. We considered our exposure to Apple through our holdings of Berkshire stock to be sufficient, and we ended up making a lot of money on it. There has been a great deal of speculation in the market about what Buffett’s sale of Apple signals regarding his view of the stock market. I think the reason for the sale is much simpler. Buffett probably considers Apple stock so expensive that he prefers to cash in at 20% less (after all, Berkshire must pay tax on its profits). He started selling in the first quarter of the year. When I was in Omaha for the general meeting in May, Buffett said he was still selling, and I expect he continued to do so in the third quarter. I have to say that, as a Berkshire shareholder, I am happy about the Apple sale. I think Berkshire’s management will find a better use for this money, as they always have in the past. It is quite likely that they already have a very specific idea about this. If that takes two or three years, it does not matter at all. This is not a race and, in the meantime, the risk of holding Berkshire Hathaway stock itself has been greatly reduced.”


""")
# Out:
# Amazon.com (NASDAQ:AMZN) has taken a bearish stance on its stock, with its large volume and open interest of $1,112,852 and $4,006,834. This indicates that whales have been targeting a price range from $70.0 to $200.0 for Amazon.com over the last 3 months, and the overall sentiment of these big-money traders is split between 40% bullish and 59%, bearish. JP Morgan has decided to maintain their Overweight rating on Amazon. Needham and Barclays have also upgraded their Buy ratings to Outperform with a price target of $160. If you want to stay updated on the latest options trades, Benzinga Pro gives you real-time options trades alerts.
# [{'label': 'neutral', 'score': 0.850114107131958}]

# %%
df['sentiment'][0]
# Out:
# '{"positive":0.21119389,"negative":0.029195568,"neutral":0.75961053}'

# %%
df['pubDate'] = pd.to_datetime(df['pubDate'], errors='coerce')
df['pubDate'] = df['pubDate'].dt.date

df.head()
# Out:
#                                                  url  \
# 0  https://www.benzinga.com/markets/options/23/09...
# 1  https://www.investors.com/news/technology/amaz...
# 2  https://www.benzinga.com/insights/options/24/0...
# 3  https://www.benzinga.com/insights/news/24/10/4...
# 4  https://www.barrons.com/articles/-amazon-care-...
#
#                               authorsByline                         articleId  \
# 0                         Benzinga Insights  3e0977d3ab0c46a3a63f3c54be31559c
# 1  PATRICK SEITZ, Investor's Business Daily  d87e2715819b4c768df970877cc3adc9
# 2                         Benzinga Insights  ccd56c53f85e4048a18d3c5558d24962
# 3                         Benzinga Insights  3269f58619154c55b08d8b58dc68b4a5
# 4                            Eric J. Savitz  078d5e6f599a4ecdbcd64840242c1757
#
#                           clusterId  \
# 0  5a7db019e1784220b7f9f1820f7d76de
# 1  43fcd4eaf99c4e658f2ea8937bb3b1a1
# 2  4dfd303d36194063a2259979e2f08951
# 3  f48106320e3542d196af0d216b604eee
# 4  7352bfbd21434aa4bab91cf5eb4514a1
#
#                                               source  \
# 0  {"domain":"benzinga.com","paywall":false,"loca...
# 1  {"domain":"investors.com","paywall":true,"loca...
# 2  {"domain":"benzinga.com","paywall":false,"loca...
# 3  {"domain":"benzinga.com","paywall":false,"loca...
# 4  {"domain":"barrons.com","paywall":true,"locati...
#
#                                             imageUrl country language  \
# 0  https://cdn.benzinga.com/files/images/story/20...      us       en
# 1  https://www.investors.com/wp-content/uploads/2...      us       en
# 2  https://cdn.benzinga.com/files/images/story/20...      us       en
# 3  https://cdn.benzinga.com/files/images/story/20...      us       en
# 4        https://images.barrons.com/im-608344/social      us       en
#
#       pubDate                           addDate  ...  \
# 0  2023-09-01  2023-09-01T20:28:10.586136+00:00  ...
# 1  2022-08-05  2022-08-05T14:03:06.437850+00:00  ...
# 2  2024-09-25  2024-09-25T17:47:54.002068+00:00  ...
# 3  2024-10-23  2024-10-25T23:31:30.291124+00:00  ...
# 4  2022-08-24  2022-08-24T23:39:20.583059+00:00  ...
#
#                                              summary  translation  \
# 0  Amazon.com (NASDAQ:AMZN) has taken a bearish s...          NaN
# 1  E-commerce giant Amazon (AMZN) on Friday annou...          NaN
# 2  Amazon.com (NASDAQ:AMZN) has seen unusual acti...          NaN
# 3  Amazon.com (NASDAQ:AMZN) shares are currently ...          NaN
# 4  Amazon is shutting down Amazon Care, a healthc...          NaN
#
#   translatedTitle translatedDescription locations reprint  \
# 0             NaN                   NaN        []   False
# 1             NaN                   NaN        []   False
# 2             NaN                   NaN        []   False
# 3             NaN                   NaN        []   False
# 4             NaN                   NaN        []   False
#
#                      reprintGroupId places people  translatedSummary
# 0  4ee337b9dcbf4525a81b7a5183664bf0     []     []                NaN
# 1  5ecef2bfc08a4829abc39e5bc95487d2    NaN    NaN                NaN
# 2  86d94c97ebcf4d8ebe50e81f3d83636a     []     []                NaN
# 3  dd83e1c061cb4a8eb4013af7bbe6e274     []     []                NaN
# 4  bdf340ec49bc4236af501bb87bbb88f3    NaN    NaN                NaN
#
# [5 rows x 37 columns]

# %%
from datetime import timedelta
import sys
sys.path.append('/Users/kailiu/StockMarketPrediction-') 

from utils import APIs
next_day = df['pubDate'][0] + timedelta(days=1)
df_stock = APIs.download_stock_data('AAPL', '2024-11-25', '2024-11-26', '1d')
print(df_stock)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close    High         Low        Open    Volume
# Date
# 2024-11-25  232.869995  232.869995  233.25  229.740005  231.460007  89984500
